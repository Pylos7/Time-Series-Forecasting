# %% [markdown]
# # Libraries, directory and data

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv("nyc_data.csv", index_col=0, parse_dates=True)
df.head()
# Out:
#                 Demand  Easter  Thanksgiving  Christmas  Temperature  \
# Date
# 2015-01-01  720.000885       0             0          0         3.68
# 2015-01-02  581.276773       0             0          0         4.73
# 2015-01-03  754.117039       0             0          0         7.23
# 2015-01-04  622.252774       0             0          0        10.96
# 2015-01-05  785.373319       0             0          0         6.92
#
#             Marketing
# Date
# 2015-01-01     41.305
# 2015-01-02    131.574
# 2015-01-03    162.700
# 2015-01-04    160.281
# 2015-01-05     51.077

# %%
# Rename variable
df = df.rename(columns = {"Demand": "y"})
df.head(0)
# Out:
# Empty DataFrame
# Columns: [y, Easter, Thanksgiving, Christmas, Temperature, Marketing]
# Index: []

# %%
# Summary statistics
df.describe().transpose()
# Out:
#                count        mean         std        min         25%  \
# y             2192.0  756.059227  152.143070  425.77532  641.161123
# Easter        2192.0    0.002737    0.052259    0.00000    0.000000
# Thanksgiving  2192.0    0.002737    0.052259    0.00000    0.000000
# Christmas     2192.0    0.002737    0.052259    0.00000    0.000000
# Temperature   2192.0   15.012655    8.772751   -8.85000    7.767500
# Marketing     2192.0  126.675890   58.274047   24.58900   78.303500
#
#                     50%         75%          max
# y             736.94763  855.645886  1384.908525
# Easter          0.00000    0.000000     1.000000
# Thanksgiving    0.00000    0.000000     1.000000
# Christmas       0.00000    0.000000     1.000000
# Temperature    14.89500   23.230000    30.900000
# Marketing     122.76450  169.395250   299.860000

# %% [markdown]
# # Seasonal Decomposition

# %%
# Decomposition
decomposition = seasonal_decompose(x = df.y,
                                   model= "multiplicative",
                                   period = 365)
decomposition.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Desktop\Time Series Forecasting Product\env\Lib\site-packages\statsmodels\graphics\utils.py:10, in _import_mpl()
#       9 try:
# ---> 10     import matplotlib.pyplot as plt
#      11 except:
#
# ModuleNotFoundError: No module named 'matplotlib'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 5
#       1 # Decomposition
#       2 decomposition = seasonal_decompose(x = df.y,
#       3                                    model= "multiplicative",
#       4                                    period = 365)
# ----> 5 decomposition.plot()
#
# File ~\Desktop\Time Series Forecasting Product\env\Lib\site-packages\statsmodels\tsa\seasonal.py:317, in DecomposeResult.plot(self, observed, seasonal, trend, resid, weights)
#     313 from pandas.plotting import register_matplotlib_converters
#     315 from statsmodels.graphics.utils import _import_mpl
# --> 317 plt = _import_mpl()
#     318 register_matplotlib_converters()
#     319 series = [(self._observed, "Observed")] if observed else []
#
# File ~\Desktop\Time Series Forecasting Product\env\Lib\site-packages\statsmodels\graphics\utils.py:12, in _import_mpl()
#      10     import matplotlib.pyplot as plt
#      11 except:
# ---> 12     raise ImportError("Matplotlib is not found.")
#      14 return plt
#
# ImportError: Matplotlib is not found.
