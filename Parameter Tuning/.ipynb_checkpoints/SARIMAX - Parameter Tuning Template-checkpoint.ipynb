# %%
#libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ParameterGrid
import pmdarima as pm
from pmdarima import model_selection

# %%
#load the data
#YYYY-MM-DD
df = pd.read_csv('../nyc_data.csv', index_col = 0, parse_dates = True)
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Demand, Easter, Thanksgiving, Christmas, Temperature, Marketing]
# Index: []

# %%
#Rename variable
df = df.rename(columns = {'Demand': 'y'})
df.head(1)
# Out:
#                      y  Easter  Thanksgiving  Christmas  Temperature  \
# Date
# 2015-01-01  720.000885       0             0          0         3.68
#
#             Marketing
# Date
# 2015-01-01     41.305

# %%
# Extract regressors
X = df.iloc[:,1:]
X.head(0)
# Out:
# Empty DataFrame
# Columns: [Easter, Thanksgiving, Christmas, Temperature, Marketing]
# Index: []

# %% [markdown]
# # Stationarity

# %%
# Test
from statsmodels.tsa.stattools import adfuller
pvalue = adfuller(x = df.y)[1]

# Condition to read test
if pvalue < 0.05:
    print(f"The Time Series is Stationary. The P-Value is {pvalue:.3f}")
else:
    print(f"The Time Series is Not Stationary. The P-Value is {pvalue:.3f}")
# Out:
# The Time Series is Not Stationary. The P-Value is 0.377

# %%
# Differencing
pvalue = adfuller(df.y.diff().dropna())[1]

# Condition to read test
if pvalue < 0.05:
    print(f"The Time Series is Stationary. The P-Value is {pvalue:.3f}")
else:
    print(f"The Time Series is Not Stationary. The P-Value is {pvalue:.3f}")
# Out:
# The Time Series is Stationary. The P-Value is 0.000

# %% [markdown]
# # SARIMAX Model

# %%
# Model
# hourly: 24, daily: 7, weekly:52, monthly:12, quarterly:4
model = pm.ARIMA(order = (1, 1, 1),
                 seasonal_order = (1, 1, 1, 7),
                 suppress_warnings = True,
                 force_stationarity = False)

# %%
# Cross-Validation
cv = model_selection.RollingForecastCV(h = 31,
                                       step = 16,
                                       initial = df.shape[0] - 180)
cv_score = model_selection.cross_val_score(model,
                                           y = df.y,
                                           X = X,
                                           scoring = 'mean_squared_error',
                                           cv = cv,
                                           verbose = 2,
                                           error_score = 10000000000000 
                                           )
# Out:
# [CV] fold=0 ..........................................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 5
#       1 # Cross-Validation
#       2 cv = model_selection.RollingForecastCV(h = 31,
#       3                                        step = 16,
#       4                                        initial = df.shape[0] - 180)
# ----> 5 cv_score = model_selection.cross_val_score(model,
#       6                                            y = df.y,
#       7                                            X = X,
#       8                                            scoring = 'mean_squared_error',
#       9                                            cv = cv,
#      10                                            verbose = 2,
#      11                                            error_score = 10000000000000
#      12                                            )
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\pmdarima\model_selection\_validation.py:400, in cross_val_score(estimator, y, X, scoring, cv, verbose, error_score)
#     358 def cross_val_score(
#     359     estimator,
#     360     y,
#    (...)
#     365     error_score=np.nan,
#     366 ):
#     367     """Evaluate a score by cross-validation
#     368
#     369     Parameters
#    (...)
#     398         does not affect the refit step, which will always raise the error.
#     399     """
# --> 400     cv_results = cross_validate(
#     401         estimator=estimator,
#     402         y=y,
#     403         X=X,
#     404         scoring=scoring,
#     405         cv=cv,
#     406         verbose=verbose,
#     407         error_score=error_score,
#     408     )
#     409     return cv_results['test_score']
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\pmdarima\model_selection\_validation.py:199, in cross_validate(estimator, y, X, scoring, cv, verbose, error_score)
#     193     raise ValueError('error_score should be the string "raise" or a '
#     194                      'numeric value')
#     196 # TODO: in the future we might consider joblib for parallelizing, but it
#     197 #   . could cause cross threads in parallelism..
# --> 199 results = [
#     200     _fit_and_score(fold,
#     201                    base.clone(estimator),
#     202                    y,
#     203                    X,
#     204                    scorer=scoring,
#     205                    train=train,
#     206                    test=test,
#     207                    verbose=verbose,
#     208                    error_score=error_score)
#     209     for fold, (train, test) in enumerate(cv.split(y, X))]
#     210 scores, fit_times, score_times = list(zip(*results))
#     212 ret = {
#     213     'test_score': np.array(scores),
#     214     'fit_time': np.array(fit_times),
#     215     'score_time': np.array(score_times),
#     216 }
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\pmdarima\model_selection\_validation.py:200, in <listcomp>(.0)
#     193     raise ValueError('error_score should be the string "raise" or a '
#     194                      'numeric value')
#     196 # TODO: in the future we might consider joblib for parallelizing, but it
#     197 #   . could cause cross threads in parallelism..
#     199 results = [
# --> 200     _fit_and_score(fold,
#     201                    base.clone(estimator),
#     202                    y,
#     203                    X,
#     204                    scorer=scoring,
#     205                    train=train,
#     206                    test=test,
#     207                    verbose=verbose,
#     208                    error_score=error_score)
#     209     for fold, (train, test) in enumerate(cv.split(y, X))]
#     210 scores, fit_times, score_times = list(zip(*results))
#     212 ret = {
#     213     'test_score': np.array(scores),
#     214     'fit_time': np.array(fit_times),
#     215     'score_time': np.array(score_times),
#     216 }
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\pmdarima\model_selection\_validation.py:85, in _fit_and_score(fold, estimator, y, X, scorer, train, test, verbose, error_score)
#      82 y_train, y_test, X_train, X_test = _safe_split(y, X, train, test)
#      84 try:
# ---> 85     estimator.fit(y_train, X=X_train)
#      87 except Exception as e:
#      88     fit_time = time.time() - start_time
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\pmdarima\arima\arima.py:603, in ARIMA.fit(self, y, X, **fit_args)
#     600         X = safe_indexing(X, slice(0, n_exog - cv))
#     602 # Internal call
# --> 603 self._fit(y, X, **fit_args)
#     605 # now make a forecast if we're validating to compute the
#     606 # out-of-sample score
#     607 if cv_samples is not None:
#     608     # get the predictions (use self.predict, which calls forecast
#     609     # from statsmodels internally)
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\pmdarima\arima\arima.py:524, in ARIMA._fit(self, y, X, **fit_args)
#     522     with warnings.catch_warnings(record=False):
#     523         warnings.simplefilter('ignore')
# --> 524         fit, self.arima_res_ = _fit_wrapper()
#     525 else:
#     526     fit, self.arima_res_ = _fit_wrapper()
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\pmdarima\arima\arima.py:510, in ARIMA._fit.<locals>._fit_wrapper()
#     507 _maxiter = fit_args.pop("maxiter", _maxiter)
#     509 disp = fit_args.pop("disp", 0)
# --> 510 fitted = arima.fit(
#     511     start_params=start_params,
#     512     method=method,
#     513     maxiter=_maxiter,
#     514     disp=disp,
#     515     **fit_args,
#     516 )
#     518 return arima, fitted
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:704, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702         flags['hessian_method'] = optim_hessian
#     703     fargs = (flags,)
# --> 704     mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                        fargs=fargs,
#     706                                        maxiter=maxiter,
#     707                                        full_output=full_output,
#     708                                        disp=disp, callback=callback,
#     709                                        skip_hessian=True, **kwargs)
#     711 # Just return the fitted parameters if requested
#     712 if return_params:
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\statsmodels\base\model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\statsmodels\base\optimizer.py:242, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     239     fit_funcs.update(extra_fit_funcs)
#     241 func = fit_funcs[method]
# --> 242 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     243                      disp=disp, maxiter=maxiter, callback=callback,
#     244                      retall=retall, full_output=full_output,
#     245                      hess=hessian)
#     247 optim_settings = {'optimizer': method, 'start_params': start_params,
#     248                   'maxiter': maxiter, 'full_output': full_output,
#     249                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     250                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     251 optim_settings.update(kwargs)
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\statsmodels\base\optimizer.py:659, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     656 elif approx_grad:
#     657     func = f
# --> 659 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     660                                  callback=callback, args=fargs,
#     661                                  bounds=bounds, disp=disp,
#     662                                  **extra_kwargs)
#     664 if full_output:
#     665     xopt, fopt, d = retvals
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_lbfgsb_py.py:197, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     185 # build options
#     186 opts = {'disp': disp,
#     187         'iprint': iprint,
#     188         'maxcor': m,
#    (...)
#     194         'callback': callback,
#     195         'maxls': maxls}
# --> 197 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                        **opts)
#     199 d = {'grad': res['jac'],
#     200      'task': res['message'],
#     201      'funcalls': res['nfev'],
#     202      'nit': res['nit'],
#     203      'warnflag': res['status']}
#     204 f = res['fun']
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_lbfgsb_py.py:359, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     353 task_str = task.tobytes()
#     354 if task_str.startswith(b'FG'):
#     355     # The minimization routine wants f and g at the current x.
#     356     # Note that interruptions due to maxfun are postponed
#     357     # until the completion of the current minimization iteration.
#     358     # Overwrite f and g:
# --> 359     f, g = func_and_grad(x)
#     360 elif task_str.startswith(b'NEW_X'):
#     361     # new iteration
#     362     n_iterations += 1
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_differentiable_functions.py:286, in ScalarFunction.fun_and_grad(self, x)
#     284     self._update_x_impl(x)
#     285 self._update_fun()
# --> 286 self._update_grad()
#     287 return self.f, self.g
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\statsmodels\base\model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:933, in MLEModel.loglike(self, params, *args, **kwargs)
#     927 transformed, includes_fixed, complex_step, kwargs = _handle_args(
#     928     MLEModel._loglike_param_names, MLEModel._loglike_param_defaults,
#     929     *args, **kwargs)
#     931 params = self.handle_params(params, transformed=transformed,
#     932                             includes_fixed=includes_fixed)
# --> 933 self.update(params, transformed=True, includes_fixed=True,
#     934             complex_step=complex_step)
#     936 if complex_step:
#     937     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#
# File ~\Desktop\Time Series Forecasting Product\env\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1644, in SARIMAX.update(self, params, transformed, includes_fixed, complex_step)
#    1639 # Observation intercept
#    1640 # Exogenous data with MLE estimation of parameters enters through a
#    1641 # time-varying observation intercept (is equivalent to simply
#    1642 # subtracting it out of the endogenous variable first)
#    1643 if self.mle_regression:
# -> 1644     self.ssm['obs_intercept'] = np.dot(self.exog, params_exog)[None, :]
#    1646 # State intercept (Harvey) or additional observation intercept
#    1647 # (Hamilton)
#    1648 # SARIMA trend enters through the a time-varying state intercept,
#    1649 # associated with the first row of the stationary component of the
#    1650 # state vector (i.e. the first element of the state vector following
#    1651 # any differencing elements)
#    1652 if self._k_trend > 0:
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# CV performance
np.sqrt(np.average(cv_score))
# Out:
# 60.721916951512476

# %% [markdown]
# # Parameter tuning

# %%
# Grid
param_grid = {'p': [0, 1],
              'd': [0, 1],
              'q': [0, 1],
              'P': [0, 1],
              'D': [0, 1],
              'Q': [0, 1]}
grid = ParameterGrid(param_grid)
len(list(grid))
# Out:
# 64

# %%
# Paramter tuning
rmse = []
i = 1
# Parameter loop
for params in grid:
    print(f"{i} / {len(list(grid))}")
    # Model
    model = pm.ARIMA(order = (params['p'], params['d'], params['q']),
                 seasonal_order = (params['P'], params['D'], params['Q'], 7),
                 suppress_warnings = True,
                 force_stationarity = False)
    
    # CV
    cv = model_selection.RollingForecastCV(h = 31,
                                       step = 16,
                                       initial = df.shape[0] - 180)
    cv_score = model_selection.cross_val_score(model,
                                               y = df.y,
                                               X = X,
                                               scoring = 'mean_squared_error',
                                               cv = cv,
                                               verbose = 2,
                                               error_score = 100000 
                                               )
    
    # Error
    error = np.sqrt(np.average(cv_score))
    rmse.append(error)
    
    i += 1
# Out:
# 1 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 2 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 3 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 4 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 5 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 6 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 7 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 8 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 9 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 10 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 11 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 12 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 13 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 14 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 15 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 16 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 17 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 18 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 19 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 20 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 21 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 22 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 23 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 24 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 25 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 26 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 27 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 28 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 29 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 30 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 31 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 32 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 33 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 34 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 35 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 36 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 37 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 38 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 39 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 40 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 41 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 42 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 43 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 44 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 45 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 46 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 47 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 48 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 49 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 50 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 51 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 52 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 53 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 54 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 55 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 56 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 57 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 58 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 59 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 60 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 61 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 62 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 63 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................
# 64 / 64
# [CV] fold=0 ..........................................................
# [CV] fold=1 ..........................................................
# [CV] fold=2 ..........................................................
# [CV] fold=3 ..........................................................
# [CV] fold=4 ..........................................................
# [CV] fold=5 ..........................................................
# [CV] fold=6 ..........................................................
# [CV] fold=7 ..........................................................
# [CV] fold=8 ..........................................................
# [CV] fold=9 ..........................................................

# %%
tuning_results = pd.DataFrame(grid)
tuning_results['rmse'] = rmse
tuning_results
# Out:
#     D  P  Q  d  p  q        rmse
# 0   0  0  0  0  0  0   84.175026
# 1   0  0  0  0  0  1   85.346385
# 2   0  0  0  0  1  0   85.468585
# 3   0  0  0  0  1  1   86.926921
# 4   0  0  0  1  0  0  110.266531
# .. .. .. .. .. .. ..         ...
# 59  1  1  1  0  1  1   59.516682
# 60  1  1  1  1  0  0   68.057139
# 61  1  1  1  1  0  1   59.731855
# 62  1  1  1  1  1  0   62.388030
# 63  1  1  1  1  1  1   59.585420
#
# [64 rows x 7 columns]

# %%
#export best parameters
best_params = tuning_results[tuning_results.rmse == tuning_results.rmse.min()].transpose()
best_params.to_csv("../Forecasting Product/best_params_sarimax.csv")
best_params
# Out:
#              43
# D      1.000000
# P      0.000000
# Q      1.000000
# d      0.000000
# p      1.000000
# q      1.000000
# rmse  59.216808
